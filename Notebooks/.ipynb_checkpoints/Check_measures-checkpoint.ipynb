# %%
#import libraries that we need

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

from sklearn import linear_model
from sklearn.cross_validation import train_test_split
from sklearn import metrics
from sklearn.metrics import r2_score

from sklearn.linear_model import Lasso

# %matplotlib inline

# %%
#Read data from a csv file into a Pandas.Dataframe

df = pd.read_csv('../data/promise/ckset.csv')
df = df.drop(['name', 'version', 'namep'], axis=1)

df2 = df[df.bug == 0]

print (len(df))
# Out:
# 16626

# %%
df.head()
# Out:
#    wmc  dit  noc  cbo  rfc  lcom  ca  ce  npm     lcom3 ...     dam  moa  \
# 0   16    3    0    6   52   112   1   5   11  0.777778 ...   1.000    0
# 1   12    2   14   23   23     0  17   8   12  0.363636 ...   1.000    2
# 2   53    1    0   34  150  1362  22  15   49  1.001603 ...   0.375    0
# 3   49    3    2   43  100  1176  34  12   46  1.000000 ...   0.000    1
# 4    1    1    0    5    1     0   5   1    1  2.000000 ...   0.000    0
#
#         mfa       cam  ic  cbm        amc  max_cc  avg_cc  bug
# 0  0.740000  0.344444   2    8  30.625000       1  0.8125    0
# 1  0.731707  0.218750   1    7  11.250000       5  1.5833    0
# 2  0.000000  0.125000   0    0  37.962264      49  4.3962    1
# 3  0.606838  0.122222   3   21  14.142857      16  1.8571    0
# 4  0.000000  1.000000   0    0   0.000000       1  1.0000    0
#
# [5 rows x 21 columns]

# %%
features = list(df)

print (features)
# Out:
# ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom', 'ca', 'ce', 'npm', 'lcom3', 'loc', 'dam', 'moa', 'mfa', 'cam', 'ic', 'cbm', 'amc', 'max_cc', 'avg_cc', 'bug']

# %%
l = []
ll = []

# %%
for xstr in features:
    for ystr in features:
        
        if xstr == ystr:
            continue
        
        x = np.array(df[xstr])
        y = np.array(df[ystr])
        
        datax_train, datax_test, datay_train, datay_test = train_test_split(x, y, test_size=0.20, random_state=42)
        
        # Create a LinearRegression Model
        linear_reg = linear_model.LinearRegression()
        
        # Make data ready to fit the model
        datax_train = np.atleast_2d(datax_train).T
        datay_train = np.atleast_2d(datay_train).T
        datax_test = np.atleast_2d(datax_test).T
        datay_test = np.atleast_2d(datay_test).T
        
        # Fit the model with training data
        linear_reg.fit(datax_train, datay_train)
        
        # Get the prediction for testing data
        predict = linear_reg.predict(datax_test)
        
        # Get the score
        l.append((xstr, ystr, r2_score(datay_test, predict)))
        
        print ()
      
        plt.scatter(datax_test, datay_test,  color='black')
        plt.plot(datax_test, predict, color='blue', linewidth=3)

        #plt.xticks(())
        #plt.yticks(())

        plt.show()

# %%
for xstr in features:
    for ystr in features:
        
        if xstr == ystr:
            continue
        
        x = np.array(df2[xstr])
        y = np.array(df2[ystr])
        
        datax_train, datax_test, datay_train, datay_test = train_test_split(x, y, test_size=0.20, random_state=42)
        
        # Create a LinearRegression Model
        linear_reg = linear_model.LinearRegression()
        
        # Make data ready to fit the model
        datax_train = np.atleast_2d(datax_train).T
        datay_train = np.atleast_2d(datay_train).T
        datax_test = np.atleast_2d(datax_test).T
        datay_test = np.atleast_2d(datay_test).T
        
        # Fit the model with training data
        linear_reg.fit(datax_train, datay_train)
        
        # Get the prediction for testing data
        predict = linear_reg.predict(datax_test)
        
        # Get the score
        ll.append((xstr, ystr, r2_score(datay_test, predict)))

# %%
s = list(set(sorted(l, key=lambda x: x[2], reverse=True)))
s2 = (sorted(ll, key=lambda x: x[2], reverse=True))

# %%
for t in s:
    if t[2] > 0.65:
        if t[0] == 'bug' or t[1] == 'bug':
                continue
        else:
            print (t[0], t[1], 'Score: ', t[2])
# Out:
# npm wmc Score:  0.772598733637
# dit mfa Score:  0.692279373944
# wmc rfc Score:  0.703341648844
# cbo ca Score:  0.846630248775
# mfa dit Score:  0.692310481494
# rfc wmc Score:  0.704893435748
# wmc npm Score:  0.771253855237
# ca cbo Score:  0.846639929941

# %%
for t in s2:
    if t[2] > 0.65:
        if t[1] == 'bug':
                continue
        else:
            print (t[0], t[1], 'Score: ', t[2])
# Out:
# ca cbo Score:  0.813292164465
# cbo ca Score:  0.813012984968
# dit mfa Score:  0.682913040678
# mfa dit Score:  0.682814383309
